# %% [markdown]
# # ¿Cómo y dónde gasta el Estado chileno a través de Mercado Público, y dónde están las mejores oportunidades para un proveedor? #

# %%
#importamos librerias

import pandas as pd
import numpy as np

#Dado que los archivos tiene la misma estructura uso glob.

import glob


archivos = glob.glob('C:/Users/OAD/Documents/mercado-publico-eda/data/raw/*.csv')
df = pd.concat([pd.read_csv(f, sep=';', encoding='Latin-1') for f in archivos], ignore_index=True)
# Out:
# C:\Users\OAD\AppData\Local\Temp\ipykernel_19816\2173574882.py:12: DtypeWarning: Columns (21,31,53,73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.concat([pd.read_csv(f, sep=';', encoding='Latin-1') for f in archivos], ignore_index=True)
# C:\Users\OAD\AppData\Local\Temp\ipykernel_19816\2173574882.py:12: DtypeWarning: Columns (21,31,73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.concat([pd.read_csv(f, sep=';', encoding='Latin-1') for f in archivos], ignore_index=True)
# C:\Users\OAD\AppData\Local\Temp\ipykernel_19816\2173574882.py:12: DtypeWarning: Columns (21,31,73,74) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.concat([pd.read_csv(f, sep=';', encoding='Latin-1') for f in archivos], ignore_index=True)

# %% [markdown]
# *Chequeamos duplicados perfectos*

# %%
#Borramos entradas duplicadas
print(df.duplicated().sum().sum())
# Out:
# 0

# %% [markdown]
# *No existen entradas duplicadas en el dataset.*

# %%
df.shape #Comprobamos shape
# Out:
# (1124505, 78)

# %%
df.columns.tolist() #Chequeamos columnas.
# Out:
# ['ID',
#  'Codigo',
#  'Link',
#  'Nombre',
#  'Descripcion/Obervaciones',
#  'Tipo',
#  'ProcedenciaOC',
#  'EsTratoDirecto',
#  'EsCompraAgil',
#  'CodigoTipo',
#  'CodigoAbreviadoTipoOC',
#  'DescripcionTipoOC',
#  'codigoEstado',
#  'Estado',
#  'codigoEstadoProveedor',
#  'EstadoProveedor',
#  'FechaCreacion',
#  'FechaEnvio',
#  'FechaSolicitudCancelacion',
#  'fechaUltimaModificacion',
#  'FechaAceptacion',
#  'FechaCancelacion',
#  'tieneItems',
#  'PromedioCalificacion',
#  'CantidadEvaluacion',
#  'MontoTotalOC',
#  'TipoMonedaOC',
#  'MontoTotalOC_PesosChilenos',
#  'Impuestos',
#  'TipoImpuesto',
#  'Descuentos',
#  'Cargos',
#  'TotalNetoOC',
#  'CodigoUnidadCompra',
#  'RutUnidadCompra',
#  'UnidadCompra',
#  'CodigoOrganismoPublico',
#  'OrganismoPublico',
#  'sector',
#  'ActividadComprador',
#  'CiudadUnidadCompra',
#  'RegionUnidadCompra',
#  'PaisUnidadCompra',
#  'CodigoSucursal',
#  'RutSucursal',
#  'Sucursal',
#  'CodigoProveedor',
#  'NombreProveedor',
#  'ActividadProveedor',
#  'ComunaProveedor',
#  'RegionProveedor',
#  'PaisProveedor',
#  'Financiamiento',
#  'PorcentajeIva',
#  'Pais',
#  'TipoDespacho',
#  'FormaPago',
#  'CodigoLicitacion',
#  'Codigo_ConvenioMarco',
#  'IDItem',
#  'codigoCategoria',
#  'Categoria',
#  'codigoProductoONU',
#  'NombreroductoGenerico',
#  'RubroN1',
#  'RubroN2',
#  'RubroN3',
#  'EspecificacionComprador',
#  'EspecificacionProveedor',
#  'cantidad',
#  'UnidadMedida',
#  'monedaItem',
#  'precioNeto',
#  'totalCargos',
#  'totalDescuentos',
#  'totalImpuestos',
#  'totalLineaNeto',
#  'Forma de Pago']

# %% [markdown]
# *Se consideran las columnas utiles para el analisis.*
# *Se crea una nueva tabla con las columnas utiles para su posterior limpieza y validación*

# %%
print("IDs unicas :", df["ID"].nunique())
print("Filas totales :", df.shape[0])
# Out:
# IDs unicas : 401077
# Filas totales : 1124505

# %%
cols = ['ID', 'OrganismoPublico', "Estado", 'sector', 'FechaEnvio', 'NombreProveedor', "CodigoProveedor", 'ActividadProveedor', 'Categoria', 'RubroN1', "RegionUnidadCompra", "TipoMonedaOC", "totalLineaNeto"]
df_limpieza = df[cols].copy()
df_limpieza.sample(20) #Se verifica la creación de la nueva tabla.
# Out:
#                ID                                   OrganismoPublico  \
# 1085156  54549940                     I MUNICIPALIDAD DE PANGUIPULLI
# 1064659  54540674                          UNIVERSIDAD DE VALPARAISO
# 359064   54142751                      I MUNICIPALIDAD DE SANTA CRUZ
# 1040267  54530307                      I MUNICIPALIDAD DE SAN MIGUEL
# 297527   54221421                      INSTITUTO DE PREVISION SOCIAL
# 241384   54193698              DIRECCION DE LOGISTICA DE CARABINEROS
# 254673   54199566                    DIVISION LOGISTICA DEL EJERCITO
# 466080   54287209  CORPORACION MUNICIPAL DE PENALOLEN PARA EL DES...
# 1057566  54537614           DIRECCION DE ABASTECIMIENTO DE LA ARMADA
# 921217   54474012                      I MUNICIPALIDAD DE PICHIDEGUA
# 669722   54377344           CORPORACION MUNIC DE EDUC SALUD ATENCION
# 964251   54493838                        I MUNICIPALIDAD DE COQUIMBO
# 953299   54488999                               UNIVERSIDAD DE CHILE
# 960898   54492332           DIRECCION DE ABASTECIMIENTO DE LA ARMADA
# 1000657  54509994                        I MUNICIPALIDAD DE COQUIMBO
# 786578   54416270      HOSPITAL COMPLEJO ASISTENCIAL PADRE LAS CASAS
# 564575   54330778                           I MUNICIPALIDAD DE PUCON
# 608290   54350596                        I MUNICIPALIDAD DE QUILLECO
# 341967   54247274             I MUNICIPALIDAD DE SAN PEDRO DE LA PAZ
# 266248   54204930           DIRECCION GENERAL DE GENDARMERIA DE CHIL
#
#                      Estado                       sector  FechaEnvio  \
# 1085156  Recepcion Conforme              Municipalidades  2026-03-26
# 1064659            Aceptada  Gob. Central, Universidades  2026-03-30
# 359064   Recepcion Conforme              Municipalidades  2026-02-12
# 1040267  Recepcion Conforme              Municipalidades  2026-03-24
# 297527   Recepcion Conforme  Gob. Central, Universidades  2026-01-27
# 241384   Recepcion Conforme                         FFAA  2026-01-26
# 254673   Recepcion Conforme                         FFAA  2026-01-23
# 466080             Aceptada              Municipalidades  2026-02-06
# 1057566  Recepcion Conforme                         FFAA  2026-03-25
# 921217             Aceptada              Municipalidades  2026-03-16
# 669722             Aceptada              Municipalidades  2026-02-25
# 964251   Recepcion Conforme              Municipalidades  2026-03-18
# 953299   Recepcion Conforme  Gob. Central, Universidades  2026-03-17
# 960898   Recepcion Conforme                         FFAA  2026-03-17
# 1000657  Recepcion Conforme              Municipalidades  2026-03-27
# 786578   Recepcion Conforme                        Otros  2026-03-18
# 564575             Aceptada              Municipalidades  2026-02-16
# 608290             Aceptada              Municipalidades  2026-02-20
# 341967             Aceptada              Municipalidades  2026-01-30
# 266248   Recepcion Conforme  Gob. Central, Universidades  2026-01-23
#
#                                          NombreProveedor  CodigoProveedor  \
# 1085156                                COMERCIAL GBG SPA          1798212
# 1064659                            SERVICIOS VINCENT SPA          1899259
# 359064                                      AMINORTE S A            30679
# 1040267        COMERCIALIZADORA Y DISTRIBUIDORA IGPA SPA          1962620
# 297527                                IDC INDUSTRIAL SPA          1711634
# 241384            INDUSTRIA DISTRIBUIDORA DE MERCADO SPA          1901024
# 254673                            COMERCIAL MSM LIMITADA          1419384
# 466080                                   HOSPIMEDICA SPA          1918544
# 1057566                       MUNNICH PHARMA MEDICAL SPA            24141
# 921217                             CARPEDENT MEDICAL SPA          2022323
# 669722                                     GASCO GLP S A            27247
# 964251      PBS: Producción de Biosustratos Decorativos.          1553089
# 953299                                    BREAK LIMITADA          1694471
# 960898                           MARCELA GARY Y CIA LTDA            44669
# 1000657                                EL VALLE COQUIMBO          1318656
# 786578                             DROGUERIA HOFMANN SAC            39998
# 564575              COMERCIAL VENTAS ONLINE CON1CLIC SPA          1837558
# 608290     PRODUCTOS Y SERVICIOS INFORMATICOS TORRES SpA          1747904
# 341967                                 S.G.C DIESEL LTDA          1066149
# 266248   SOCIEDAD COMERCIAL DISTRIBUCION GLOBAL LIMITADA          1200095
#
#                                         ActividadProveedor  \
# 1085156  VENTA AL POR MAYOR DE PRODUCTOS FARMACEUTICOS ...
# 1064659  SUMINISTRO DE COMIDAS POR ENCARGO (SERVICIOS D...
# 359064        VENTA AL POR MAYOR DE OTROS PRODUCTOS N.C.P.
# 1040267  VENTA AL POR MAYOR DE ARTICULOS DE PAPELERIA Y...
# 297527   FABRICACION DE PRODUCTOS METALICOS PARA USO ES...
# 241384   OTRAS ACTIVIDADES DE VENTA AL POR MENOR EN COM...
# 254673   OTROS TIPOS DE VENTA AL POR MENOR NO REALIZADA...
# 466080   VENTA AL POR MAYOR DE PRODUCTOS FARMACEUTICOS ...
# 1057566  VENTA AL POR MAYOR DE PRODUCTOS FARMACEUTICOS|...
# 921217   VENTA AL POR MENOR DE PRODUCTOS FARMACEUTICOS ...
# 669722   FABRICACION DE GAS; DISTRIBUCION DE COMBUSTIBL...
# 964251   OTRAS ACTIVIDADES DE SERVICIOS CONEXAS A LA SI...
# 953299   Banqueria, Servicios de coffee break, ventas m...
# 960898   VENTA AL POR MENOR DE PRENDAS DE VESTIR EN GEN...
# 1000657  OTROS SERVICIOS AGRICOLAS N.C.P.| CORRETAJE DE...
# 786578   VENTA AL POR MAYOR DE PRODUCTOS QUIMICOS| VENT...
# 564575   VENTA AL POR MENOR DE ARTICULOS DE FERRETERIA ...
# 608290                                                 NaN
# 341967   MANTENIMIENTO Y REPARACION DE VEHICULOS AUTOMO...
# 266248   GRANDES TIENDAS - PRODUCTOS DE FERRETERIA Y PA...
#
#                                                  Categoria  \
# 1085156  Equipamiento para laboratorios / Instrumentos ...
# 1064659  Servicios de Viajes, alimentación, alojamiento...
# 359064                                                 NaN
# 1040267  Productos de papel / Productos de papel / Pape...
# 297527   Servicios de transporte, almacenaje y correo /...
# 241384                                                 NaN
# 254673   Muebles, accesorios, electrodomésticos y produ...
# 466080   Equipamiento y suministros médicos / Productos...
# 1057566  Salud, servicios sanitarios y alimentación / M...
# 921217   Artículos para estructuras, obras y construcci...
# 669722                                                 NaN
# 964251   Productos derivados de minerales, plantas y an...
# 953299   Servicios de Viajes, alimentación, alojamiento...
# 960898   Productos impresos y publicaciones / Etiquetad...
# 1000657  Artículos de fabricación y producción / Artícu...
# 786578                                                 NaN
# 564575   Equipos, accesorios y suministros de oficina /...
# 608290   Tecnologías de la información, telecomunicacio...
# 341967   Maquinaria para minería y perforación / Maquin...
# 266248   Equipos, accesorios y suministros de oficina /...
#
#                                                    RubroN1  \
# 1085156                     Equipamiento para laboratorios
# 1064659  Servicios de Viajes, alimentación, alojamiento...
# 359064                                                 NaN
# 1040267                                 Productos de papel
# 297527        Servicios de transporte, almacenaje y correo
# 241384                                                 NaN
# 254673   Muebles, accesorios, electrodomésticos y produ...
# 466080                  Equipamiento y suministros médicos
# 1057566         Salud, servicios sanitarios y alimentación
# 921217   Artículos para estructuras, obras y construcci...
# 669722                                                 NaN
# 964251   Productos derivados de minerales, plantas y an...
# 953299   Servicios de Viajes, alimentación, alojamiento...
# 960898                  Productos impresos y publicaciones
# 1000657              Artículos de fabricación y producción
# 786578                                                 NaN
# 564575        Equipos, accesorios y suministros de oficina
# 608290   Tecnologías de la información, telecomunicacio...
# 341967               Maquinaria para minería y perforación
# 266248        Equipos, accesorios y suministros de oficina
#
#                                        RegionUnidadCompra TipoMonedaOC  \
# 1085156                                Región de Los Ríos          CLP
# 1064659                             Región de Valparaíso           CLP
# 359064   Región del Libertador General Bernardo O´Higgins          CLP
# 1040267                  Región Metropolitana de Santiago          CLP
# 297527                              Región de Valparaíso           CLP
# 241384                   Región Metropolitana de Santiago          CLP
# 254673                             Región de Antofagasta           CLP
# 466080                   Región Metropolitana de Santiago          CLP
# 1057566                             Región de Valparaíso           CLP
# 921217   Región del Libertador General Bernardo O´Higgins          CLP
# 669722                   Región Metropolitana de Santiago          CLP
# 964251                                Región de Coquimbo           CLP
# 953299                   Región Metropolitana de Santiago          CLP
# 960898                                 Región del Biobío           CLP
# 1000657                               Región de Coquimbo           CLP
# 786578                            Región de la Araucanía           CLP
# 564575                            Región de la Araucanía           CLP
# 608290                                 Región del Biobío           CLP
# 341967                                 Región del Biobío           CLP
# 266248                   Región Metropolitana de Santiago          CLP
#
#         totalLineaNeto
# 1085156          10500
# 1064659         558386
# 359064           82656
# 1040267          15000
# 297527         1640000
# 241384           46050
# 254673          353100
# 466080         1020000
# 1057566          19500
# 921217          301620
# 669722          124938
# 964251         1761900
# 953299          235280
# 960898           60171
# 1000657          77792
# 786578         3020000
# 564575          148437
# 608290         2129740
# 341967           70000
# 266248            5436

# %%
column_mapping = {
    "ID": "id",
    "OrganismoPublico": "organismo_publico",
    "Estado": "estado",
    "sector": "sector",
    "FechaEnvio": "fecha_envio",
    "NombreProveedor": "nombre_proveedor",
    "CodigoProveedor": "codigo_de_proveedor",
    "ActividadProveedor": "actividad_proveedor",
    "Categoria": "categoria",
    "RubroN1": "rubro",
    "RegionUnidadCompra": "region_de_compra",
    "TipoMonedaOC": "tipo_moneda_oc",
    "totalLineaNeto": "total_linea_neto",
}
df = df.rename(columns=column_mapping)

columns_cleaning = [
    "id",
    "organismo_publico",
    "estado",
    "sector",
    "fecha_envio",
    "nombre_proveedor",
    "codigo_de_proveedor",
    "actividad_proveedor",
    "categoria",
    "rubro",
    "region_de_compra",
    "tipo_moneda_oc",
    "total_linea_neto",
]

df_limpieza = df[columns_cleaning]

# %%
df_limpieza.sample(8)
# Out:
#               id                              organismo_publico  \
# 134024  54143658  SERVICIO DE SALUD DEL MAULE HOSPITAL DE TALCA
# 540750  54320760    Servicio Local de Educación Pública Iquique
# 816329  54429415                       SERVICIO DE SALUD CHILOE
# 958855  54491491                            Hospital Villarrica
# 160476  54156068    SERVICIO NACIONAL DE SALUD HOSPITAL DE LOTA
# 325451  54237514       SERVICIO DE SALUD VALDIVIA HOSPITAL BASE
# 376350  54234435  FUNDACION MUNICIPAL DE CULTURA DE PROVIDENCIA
# 429713  54270843                  I MUNICIPALIDAD DE LAGO RANCO
#
#                     estado           sector fecha_envio  \
# 134024  Recepcion Conforme            Salud  2026-01-14
# 540750  Recepcion Conforme              NaN  2026-02-13
# 816329  Recepcion Conforme            Salud  2026-03-13
# 958855  Recepcion Conforme            Salud  2026-03-27
# 160476  Recepcion Conforme            Salud  2026-01-16
# 325451  Recepcion Conforme            Salud  2026-01-28
# 376350  Recepcion Conforme              NaN  2026-02-02
# 429713            Aceptada  Municipalidades  2026-02-04
#
#                       nombre_proveedor  codigo_de_proveedor  \
# 134024  JOHNSON Y JOHNSON DE CHILE S A                26963
# 540750             CARIBBEAN GROUP SPA              1749801
# 816329     DISTRIBUIDORA ABSA LIMITADA                22219
# 958855                     REUTTER S A                31590
# 160476                BYSERVI LIMITADA              1753716
# 325451         LABORATORIO BIOSANO S A                25371
# 376350                  Carlos Alberto              1681272
# 429713            COMERCIAL RENHET SPA              1836437
#
#                                       actividad_proveedor  \
# 134024           VENTA AL POR MAYOR DE PRODUCTOS QUIMICOS
# 540750                                                NaN
# 816329  VENTA AL POR MAYOR DE HUEVOS, LECHE, ABARROTES...
# 958855  VENTA AL POR MAYOR DE PRODUCTOS TEXTILES, PREN...
# 160476  ELABORACION DE OTROS PRODUCTOS ALIMENTICIOS N....
# 325451  FABRICACION DE PRODUCTOS FARMACEUTICOS, SUSTAN...
# 376350                              Productora de Eventos
# 429713  VENTA AL POR MAYOR DE ARTICULOS DE PERFUMERIA,...
#
#                                                 categoria  \
# 134024  Equipamiento y suministros médicos / Productos...
# 540750  Muebles y mobiliario / Muebles de alojamiento ...
# 816329                                                NaN
# 958855                                                NaN
# 160476  Alimentos, bebidas y tabaco / Frutas, verduras...
# 325451  Medicamentos y productos farmacéuticos / Agent...
# 376350  Servicios profesionales, administrativos y con...
# 429713                                                NaN
#
#                                                     rubro  \
# 134024                 Equipamiento y suministros médicos
# 540750                               Muebles y mobiliario
# 816329                                                NaN
# 958855                                                NaN
# 160476                        Alimentos, bebidas y tabaco
# 325451             Medicamentos y productos farmacéuticos
# 376350  Servicios profesionales, administrativos y con...
# 429713                                                NaN
#
#                         region_de_compra tipo_moneda_oc total_linea_neto
# 134024                 Región del Maule             CLP          2795800
# 540750              Región de Tarapacá              CLP           532320
# 816329              Región de los Lagos             CLP            30100
# 958855                         Araucanía            CLP            13500
# 160476                Región del Biobío             CLP            15200
# 325451                Región de Los Ríos            CLP           222000
# 376350  Región Metropolitana de Santiago            CLP           613000
# 429713                Región de Los Ríos            CLP            74130

# %% [markdown]
# *Dtypes*

# %%
df_limpieza.dtypes
# Out:
# id                      int64
# organismo_publico      object
# estado                 object
# sector                 object
# fecha_envio            object
# nombre_proveedor       object
# codigo_de_proveedor     int64
# actividad_proveedor    object
# categoria              object
# rubro                  object
# region_de_compra       object
# tipo_moneda_oc         object
# total_linea_neto       object
# dtype: object

# %%
df_limpieza["total_linea_neto"] = pd.to_numeric(
    df_limpieza["total_linea_neto"].str.replace(",", ".")
)
df_limpieza["total_linea_neto"] = pd.to_numeric(df_limpieza["total_linea_neto"])
df_limpieza["fecha_envio"] = pd.to_datetime(df_limpieza["fecha_envio"], format="%Y-%m-%d")
# Out:
# C:\Users\OAD\AppData\Local\Temp\ipykernel_19816\3913384357.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_limpieza["total_linea_neto"] = pd.to_numeric(
# C:\Users\OAD\AppData\Local\Temp\ipykernel_19816\3913384357.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_limpieza["total_linea_neto"] = pd.to_numeric(df_limpieza["total_linea_neto"])
# C:\Users\OAD\AppData\Local\Temp\ipykernel_19816\3913384357.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_limpieza["fecha_envio"] = pd.to_datetime(df_limpieza["fecha_envio"], format="%Y-%m-%d")

# %%
print(df_limpieza["fecha_envio"].dtypes)
print(df_limpieza["total_linea_neto"].dtypes)
# Out:
# datetime64[ns]
# float64

# %%
df_limpieza["sector"].value_counts()
# Out:
# sector
# Salud                          462792
# Municipalidades                326129
# Gob. Central, Universidades    134244
# FFAA                           119671
# Otros                           28088
# Obras Públicas                   7966
# Legislativo y judicial           6919
# Name: count, dtype: int64

# %%
df_limpieza["estado"].value_counts()
# Out:
# estado
# Recepcion Conforme        821530
# Aceptada                  292844
# Enviada a proveedor         8334
# Cancelacion solicitada      1100
# En proceso                   697
# Name: count, dtype: int64

# %%
df_limpieza_estado_clear = df_limpieza[~df_limpieza["estado"].isin(["Cancelacion solicitada", "En proceso"])]
df_limpieza = df_limpieza_estado_clear

# %%
df_limpieza["estado"].value_counts()
# Out:
# estado
# Recepcion Conforme     821530
# Aceptada               292844
# Enviada a proveedor      8334
# Name: count, dtype: int64

# %%
df_limpieza["tipo_moneda_oc"].value_counts()
# Out:
# tipo_moneda_oc
# CLP    1116249
# CLF       3463
# USD       2787
# UTM        193
# EUR         16
# Name: count, dtype: int64

# %%
df_limpieza["tipo_moneda_oc"].value_counts(normalize=True) * 100
# Out:
# tipo_moneda_oc
# CLP    99.424695
# CLF     0.308451
# USD     0.248239
# UTM     0.017191
# EUR     0.001425
# Name: proportion, dtype: float64

# %%
valor_uf = 40844
es_clf = df_limpieza["tipo_moneda_oc"] == "CLF"
df_limpieza.loc[es_clf, "total_linea_neto"] *= df_limpieza.loc[es_clf, "total_linea_neto"] * valor_uf
df_limpieza.loc[es_clf, "tipo_moneda_oc"] = "CLP"

valor_usd = 947
es_usd = df_limpieza["tipo_moneda_oc"] == "USD"
df_limpieza.loc[es_usd, "total_linea_neto"] *= df_limpieza.loc[es_usd, "total_linea_neto"] * valor_usd
df_limpieza.loc[es_usd, "tipo_moneda_oc"] = "CLP"

valor_utm = 71649
es_utm = df_limpieza["tipo_moneda_oc"] == "UTM"
df_limpieza.loc[es_utm, "total_linea_neto"] *= df_limpieza.loc[es_utm, "total_linea_neto"] * valor_utm
df_limpieza.loc[es_utm, "tipo_moneda_oc"] = "CLP"

valor_eur = 1076
es_eur = df_limpieza["tipo_moneda_oc"] == "EUR"
df_limpieza.loc[es_eur, "total_linea_neto"] *= df_limpieza.loc[es_eur, "total_linea_neto"] * valor_eur
df_limpieza.loc[es_eur, "tipo_moneda_oc"] = "CLP"

# %%
df_limpieza["tipo_moneda_oc"].value_counts(normalize=True) * 100
# Out:
# tipo_moneda_oc
# CLP    100.0
# Name: proportion, dtype: float64

# %%
df_limpieza.dtypes
# Out:
# id                              int64
# organismo_publico              object
# estado                         object
# sector                         object
# fecha_envio            datetime64[ns]
# nombre_proveedor               object
# codigo_de_proveedor             int64
# actividad_proveedor            object
# categoria                      object
# rubro                          object
# region_de_compra               object
# tipo_moneda_oc                 object
# total_linea_neto              float64
# dtype: object

# %% [markdown]
# *Outliers*

# %%
df_limpieza["total_linea_neto"].describe()
# Out:
# count    1.122701e+06
# mean     7.768993e+11
# std      7.581645e+14
# min     -1.474011e+07
# 25%      3.600000e+04
# 50%      1.500000e+05
# 75%      6.508450e+05
# max      8.031431e+17
# Name: total_linea_neto, dtype: float64

# %%
def formato_clp(valor, acronimo=True):
    if valor is None or pd.isna(valor):
        return ""

    # Opción 1: Resumido en Millones (muy común en análisis financiero en Chile)
    if acronimo and abs(valor) >= 1_000_000:
        return f"${valor / 1_000_000:,.1f}M".replace(",", "X").replace(".", ",").replace("X", ".")

    # Opción 2: Cifra entera con separador de miles chileno ($ 1.250.000)
    return f"${int(round(valor)):,}".replace(",", ".")

# %%
df_limpieza = df_limpieza[df_limpieza["total_linea_neto"] >= 0]

# %%
df_limpieza.sort_values(by="total_linea_neto", ascending=False)
# Out:
#               id                                  organismo_publico  \
# 376317  54234357                       I MUNICIPALIDAD DE RIO BUENO
# 384184  54246886                     SUBSECRETARIA DE SALUD PUBLICA
# 716667  54288307      JUNTA NACIONAL DE JARDINES         INFANTILES
# 677119  54381649              DIRECCION DE LOGISTICA DE CARABINEROS
# 29720   54061160                      I MUNICIPALIDAD DE LAS CONDES
# ...          ...                                                ...
# 39008   54092742           DIRECCION DE ABASTECIMIENTO DE LA ARMADA
# 53528   54104352                     I MUNICIPALIDAD DE LOS MUERMOS
# 883833  54457609                   I MUNICIPALIDAD DE SANTO DOMINGO
# 371255  54221912  SUBSECRETARIA DEL MINISTERIO DE EDUCACION PUBLICA
# 706920  54399669                  CORP CULTURAL Y TURISMO DE CALAMA
#
#                      estado                       sector fecha_envio  \
# 376317  Enviada a proveedor              Municipalidades  2026-02-13
# 384184   Recepcion Conforme                        Salud  2026-02-03
# 716667             Aceptada  Gob. Central, Universidades  2026-03-23
# 677119   Recepcion Conforme                         FFAA  2026-02-25
# 29720              Aceptada              Municipalidades  2026-01-24
# ...                     ...                          ...         ...
# 39008    Recepcion Conforme                         FFAA  2026-01-07
# 53528    Recepcion Conforme              Municipalidades  2026-01-05
# 883833   Recepcion Conforme              Municipalidades  2026-03-11
# 371255             Aceptada  Gob. Central, Universidades  2026-02-13
# 706920             Aceptada                          NaN  2026-02-28
#
#                                     nombre_proveedor  codigo_de_proveedor  \
# 376317                   AUTORENTAS DEL PACIFICO SPA                24629
# 384184    EMPRESA NACIONAL DE TELECOMUNICACIONES S A                41738
# 716667                                     SONDA S A                24685
# 677119                         CLOUDHESIVE CHILE SPA              1706756
# 29720                                      EnorChile                61682
# ...                                              ...                  ...
# 39008   CENTRO DE DIAGNOSTICO CLINICA MAGALLANES SPA              1242129
# 53528             ANVIC INGENIERIA E INSPECCIÓN LTDA              1444273
# 883833                     LUIS EDUARDO VERA CATALÁN              1731139
# 371255                   EMPRESA DE CORREOS DE CHILE                16120
# 706920                                  Felipe Mateo              1554810
#
#                                       actividad_proveedor  \
# 376317          ALQUILER DE AUTOS Y CAMIONETAS SIN CHOFER
# 384184       OTROS SERVICIOS DE TELECOMUNICACIONES N.C.P.
# 716667    EMPRESAS DE SERVICIOS INTEGRALES DE INFORMATICA
# 677119  VENTA AL POR MAYOR DE COMPUTADORES, EQUIPO PER...
# 29720   FABRICACION DE MOTORES Y TURBINAS| FABRICACION...
# ...                                                   ...
# 39008                                                   -
# 53528                             SERVICIOS PROFESIONALES
# 883833                                                NaN
# 371255       OTROS SERVICIOS DE TELECOMUNICACIONES N.C.P.
# 706920  Producción de eventos, servicio de producción ...
#
#                                                 categoria  \
# 376317  Servicios de transporte, almacenaje y correo /...
# 384184  Servicios basados en ingeniería, ciencias soci...
# 716667  Tecnologías de la información, telecomunicacio...
# 677119  Tecnologías de la información, telecomunicacio...
# 29720   Servicios básicos y de información pública / S...
# ...                                                   ...
# 39008   Salud, servicios sanitarios y alimentación / M...
# 53528   Consultoria / Consultoria / Arquitectura y Urb...
# 883833  Servicios de transporte, almacenaje y correo /...
# 371255  Servicios de transporte, almacenaje y correo /...
# 706920  Servicios profesionales, administrativos y con...
#
#                                                     rubro  \
# 376317       Servicios de transporte, almacenaje y correo
# 384184  Servicios basados en ingeniería, ciencias soci...
# 716667  Tecnologías de la información, telecomunicacio...
# 677119  Tecnologías de la información, telecomunicacio...
# 29720          Servicios básicos y de información pública
# ...                                                   ...
# 39008          Salud, servicios sanitarios y alimentación
# 53528                                         Consultoria
# 883833       Servicios de transporte, almacenaje y correo
# 371255       Servicios de transporte, almacenaje y correo
# 706920  Servicios profesionales, administrativos y con...
#
#                               region_de_compra tipo_moneda_oc  \
# 376317                      Región de Los Ríos            CLP
# 384184        Región Metropolitana de Santiago            CLP
# 716667        Región Metropolitana de Santiago            CLP
# 677119        Región Metropolitana de Santiago            CLP
# 29720         Región Metropolitana de Santiago            CLP
# ...                                        ...            ...
# 39008   Región de Magallanes y de la Antártica            CLP
# 53528                     Región de los Lagos             CLP
# 883833                   Región de Valparaíso             CLP
# 371255                      Región del Biobío             CLP
# 706920                  Región de Antofagasta             CLP
#
#         total_linea_neto
# 376317      8.031431e+17
# 384184      1.071691e+16
# 716667      9.212089e+15
# 677119      5.516647e+15
# 29720       5.361070e+15
# ...                  ...
# 39008       0.000000e+00
# 53528       0.000000e+00
# 883833      0.000000e+00
# 371255      0.000000e+00
# 706920      0.000000e+00
#
# [1122623 rows x 13 columns]

# %% [markdown]
# *"I MUNICIPALIDAD DE RIO BUENO" es una localidad con 33.013 habitantes, sin embargo tiene un gasto absurdo que probablemente sea error de typeo. Se procede a comprobar.*

# %%
df_limpieza_posibles_outliers = (df_limpieza[df_limpieza["nombre_proveedor"] == "AUTORENTAS DEL PACIFICO SPA"])

# %%
df_limpieza_posibles_outliers["total_linea_neto"].sort_values(ascending=False).apply(formato_clp)
# Out:
# 376317     $803.143.050.694,5M
# 410290           $2.577.002,8M
# 891253              $91.754,6M
# 104367              $66.959,4M
# 554563              $37.439,5M
#                   ...
# 213575                  $7.930
# 222956                  $7.875
# 222986                  $7.875
# 1026068                 $6.609
# 1026067                   $525
# Name: total_linea_neto, Length: 124, dtype: object

# %%
# Nota los dobles corchetes [[ ]]
df_limpieza.loc[376317]
# Out:
# id                                                              54234357
# organismo_publico                           I MUNICIPALIDAD DE RIO BUENO
# estado                                               Enviada a proveedor
# sector                                                   Municipalidades
# fecha_envio                                          2026-02-13 00:00:00
# nombre_proveedor                             AUTORENTAS DEL PACIFICO SPA
# codigo_de_proveedor                                                24629
# actividad_proveedor            ALQUILER DE AUTOS Y CAMIONETAS SIN CHOFER
# categoria              Servicios de transporte, almacenaje y correo /...
# rubro                       Servicios de transporte, almacenaje y correo
# region_de_compra                                      Región de Los Ríos
# tipo_moneda_oc                                                       CLP
# total_linea_neto                                    803143050694503296.0
# Name: 376317, dtype: object

# %% [markdown]
# *El numero no calza con ningún RUT, orden de compra, id, y tampoco se atribuye un error de lectura producto de puntación de miles (, o .). Se procede a descartar dado que es considerado error de tipeo.*

# %%
df_limpieza = df_limpieza.drop(376317)

# %%
df_limpieza.sort_values(by="total_linea_neto", ascending=False)
# Out:
#               id                              organismo_publico  \
# 384184  54246886                 SUBSECRETARIA DE SALUD PUBLICA
# 716667  54288307  JUNTA NACIONAL DE JARDINES         INFANTILES
# 677119  54381649          DIRECCION DE LOGISTICA DE CARABINEROS
# 29720   54061160                  I MUNICIPALIDAD DE LAS CONDES
# 885472  54458365                  INSTITUTO DE PREVISION SOCIAL
# ...          ...                                            ...
# 53528   54104352                 I MUNICIPALIDAD DE LOS MUERMOS
# 883833  54457609               I MUNICIPALIDAD DE SANTO DOMINGO
# 39008   54092742       DIRECCION DE ABASTECIMIENTO DE LA ARMADA
# 676824  54381519               CORPORACION CULTURAL DE MOSTAZAL
# 826335  54434618       SERVICIO SALUD SAN FELIPE LOS ANDES HOSP
#
#                     estado                       sector fecha_envio  \
# 384184  Recepcion Conforme                        Salud  2026-02-03
# 716667            Aceptada  Gob. Central, Universidades  2026-03-23
# 677119  Recepcion Conforme                         FFAA  2026-02-25
# 29720             Aceptada              Municipalidades  2026-01-24
# 885472  Recepcion Conforme  Gob. Central, Universidades  2026-03-11
# ...                    ...                          ...         ...
# 53528   Recepcion Conforme              Municipalidades  2026-01-05
# 883833  Recepcion Conforme              Municipalidades  2026-03-11
# 39008   Recepcion Conforme                         FFAA  2026-01-07
# 676824  Recepcion Conforme                          NaN  2026-02-25
# 826335            Aceptada                        Salud  2026-03-06
#
#                                     nombre_proveedor  codigo_de_proveedor  \
# 384184    EMPRESA NACIONAL DE TELECOMUNICACIONES S A                41738
# 716667                                     SONDA S A                24685
# 677119                         CLOUDHESIVE CHILE SPA              1706756
# 29720                                      EnorChile                61682
# 885472      CAJA DE COMPENSACION DE ASIGNACION FAMIL                17788
# ...                                              ...                  ...
# 53528             ANVIC INGENIERIA E INSPECCIÓN LTDA              1444273
# 883833                     LUIS EDUARDO VERA CATALÁN              1731139
# 39008   CENTRO DE DIAGNOSTICO CLINICA MAGALLANES SPA              1242129
# 676824                  LOS VILLANOS DE COLTAUCO SPA              1983550
# 826335                 MARIELA CARLA ROJAS HENRÍQUEZ              1767244
#
#                                       actividad_proveedor  \
# 384184       OTROS SERVICIOS DE TELECOMUNICACIONES N.C.P.
# 716667    EMPRESAS DE SERVICIOS INTEGRALES DE INFORMATICA
# 677119  VENTA AL POR MAYOR DE COMPUTADORES, EQUIPO PER...
# 29720   FABRICACION DE MOTORES Y TURBINAS| FABRICACION...
# 885472            GOBIERNO CENTRAL| CAJAS DE COMPENSACION
# ...                                                   ...
# 53528                             SERVICIOS PROFESIONALES
# 883833                                                NaN
# 39008                                                   -
# 676824  OTRAS ACTIVIDADES CREATIVAS, ARTISTICAS Y DE E...
# 826335  SERVICIOS DE MEDICOS PRESTADOS DE FORMA INDEPE...
#
#                                                 categoria  \
# 384184  Servicios basados en ingeniería, ciencias soci...
# 716667  Tecnologías de la información, telecomunicacio...
# 677119  Tecnologías de la información, telecomunicacio...
# 29720   Servicios básicos y de información pública / S...
# 885472  Servicios financieros, pensiones y seguros / B...
# ...                                                   ...
# 53528   Consultoria / Consultoria / Arquitectura y Urb...
# 883833  Servicios de transporte, almacenaje y correo /...
# 39008   Salud, servicios sanitarios y alimentación / M...
# 676824  Servicios editoriales, de diseño, publicidad, ...
# 826335  Servicios profesionales, administrativos y con...
#
#                                                     rubro  \
# 384184  Servicios basados en ingeniería, ciencias soci...
# 716667  Tecnologías de la información, telecomunicacio...
# 677119  Tecnologías de la información, telecomunicacio...
# 29720          Servicios básicos y de información pública
# 885472         Servicios financieros, pensiones y seguros
# ...                                                   ...
# 53528                                         Consultoria
# 883833       Servicios de transporte, almacenaje y correo
# 39008          Salud, servicios sanitarios y alimentación
# 676824  Servicios editoriales, de diseño, publicidad, ...
# 826335  Servicios profesionales, administrativos y con...
#
#                                         region_de_compra tipo_moneda_oc  \
# 384184                  Región Metropolitana de Santiago            CLP
# 716667                  Región Metropolitana de Santiago            CLP
# 677119                  Región Metropolitana de Santiago            CLP
# 29720                   Región Metropolitana de Santiago            CLP
# 885472                  Región Metropolitana de Santiago            CLP
# ...                                                  ...            ...
# 53528                               Región de los Lagos             CLP
# 883833                             Región de Valparaíso             CLP
# 39008             Región de Magallanes y de la Antártica            CLP
# 676824  Región del Libertador General Bernardo O´Higgins            CLP
# 826335                             Región de Valparaíso             CLP
#
#         total_linea_neto
# 384184      1.071691e+16
# 716667      9.212089e+15
# 677119      5.516647e+15
# 29720       5.361070e+15
# 885472      3.055581e+15
# ...                  ...
# 53528       0.000000e+00
# 883833      0.000000e+00
# 39008       0.000000e+00
# 676824      0.000000e+00
# 826335      0.000000e+00
#
# [1122622 rows x 13 columns]

# %%
df_limpieza["total_linea_neto"].sort_values(ascending=False).apply(formato_clp)
# Out:
# 384184    $10.716.907.441,4M
# 716667     $9.212.088.932,5M
# 677119     $5.516.647.204,1M
# 29720      $5.361.069.955,8M
# 885472     $3.055.580.576,1M
#                  ...
# 53528                     $0
# 883833                    $0
# 39008                     $0
# 676824                    $0
# 826335                    $0
# Name: total_linea_neto, Length: 1122622, dtype: object

# %% [markdown]
# *A pesar de haber montos altos estos son aceptables para la naturaleza de mercado publico.*

# %% [markdown]
# *Nulos*

# %%
df_limpieza.isna().sum()
# Out:
# id                          0
# organismo_publico           0
# estado                      0
# sector                  38673
# fecha_envio                 0
# nombre_proveedor            0
# codigo_de_proveedor         0
# actividad_proveedor      9145
# categoria              205491
# rubro                  205491
# region_de_compra            0
# tipo_moneda_oc              0
# total_linea_neto            0
# dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# # Tabla Limpia #

# %%
df_limpieza.sample(5)
# Out:
#               id                                organismo_publico  \
# 113826  54134121          SERVICIO DE SALUD SUR HOSPITAL EXEQUIEL
# 601564  54346729         SERVICIO DE SALUD VALPARAISO SAN ANTONIO
# 94448   54123847  SERVICIO DE SALUD ORIENTE HOSPITAL DEL SALVADOR
# 68595   54111510  SERVICIO DE SALUD ORIENTE HOSPITAL DEL SALVADOR
# 479103  54293203                  ILUSTRE MUNICIPALIDAD MELIPEUCO
#
#                     estado           sector fecha_envio  \
# 113826  Recepcion Conforme            Salud  2026-01-10
# 601564  Recepcion Conforme            Salud  2026-02-19
# 94448   Recepcion Conforme            Salud  2026-01-08
# 68595             Aceptada            Salud  2026-01-06
# 479103  Recepcion Conforme  Municipalidades  2026-02-09
#
#                             nombre_proveedor  codigo_de_proveedor  \
# 113826                 CASTILLA Y ARAGON SPA              1165300
# 601564                             MANDI SPA              1999275
# 94448                ASCEND LABORATORIES SPA              1344405
# 68595                     NOVARTIS CHILE S A                24535
# 479103  Asociados Undurraga Impresores Ltda.                36287
#
#                                       actividad_proveedor  \
# 113826  VENTA AL POR MAYOR NO ESPECIALIZADA| VENTA AL ...
# 601564   VENTA AL POR MAYOR DE CARNE Y PRODUCTOS CARNICOS
# 94448   OTRAS ACTIVIDADES EMPRESARIALES RELACIONADAS C...
# 68595   FABRICACION DE PRODUCTOS FARMACEUTICOS, SUSTAN...
# 479103  ACTIVIDADES DE SERVICIO RELACIONADA CON LA IMP...
#
#                                                 categoria  \
# 113826  Productos de papel / Productos de papel / Pape...
# 601564                                                NaN
# 94448   Medicamentos y productos farmacéuticos / Medic...
# 68595   Medicamentos y productos farmacéuticos / Agent...
# 479103  Equipos, accesorios y suministros de oficina /...
#
#                                                rubro  \
# 113826                            Productos de papel
# 601564                                           NaN
# 94448         Medicamentos y productos farmacéuticos
# 68595         Medicamentos y productos farmacéuticos
# 479103  Equipos, accesorios y suministros de oficina
#
#                         region_de_compra tipo_moneda_oc  total_linea_neto
# 113826  Región Metropolitana de Santiago            CLP            8640.0
# 601564             Región de Valparaíso             CLP           72300.0
# 94448   Región Metropolitana de Santiago            CLP          842400.0
# 68595   Región Metropolitana de Santiago            CLP          671894.0
# 479103           Región de la Araucanía             CLP            1000.0

# %%
df_limpieza.shape
# Out:
# (1122622, 13)

# %%
df_limpieza["total_linea_neto"] = df_limpieza["total_linea_neto"].astype(float)

df_limpieza.dtypes
# Out:
# id                              int64
# organismo_publico              object
# estado                         object
# sector                         object
# fecha_envio            datetime64[ns]
# nombre_proveedor               object
# codigo_de_proveedor             int64
# actividad_proveedor            object
# categoria                      object
# rubro                          object
# region_de_compra               object
# tipo_moneda_oc                 object
# total_linea_neto              float64
# dtype: object

# %% [markdown]
# ---

# %% [markdown]
# # Export #

# %%
df_limpieza.to_parquet('C:/Users/OAD/Documents/mercado-publico-eda/data/processed/mercado_publico_eda_clean.parquet', index=False)
